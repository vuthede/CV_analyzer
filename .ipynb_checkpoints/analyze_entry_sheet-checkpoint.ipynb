# %%
import pandas as pd
from pprint import pprint
from googletrans import Translator
from collections import Counter
import matplotlib.pyplot as plt

df = pd.read_csv('data.csv')

# %%
df_groupby_type = df.groupby(['いつの選考ですか'])[['このESはES選考を通過しましたか', 'この企業の最終的な選考結果を教えてください']]
groups = df_groupby_type.groups
keys = groups.keys()

# %%
print("In {} ({}):\n".format('このESはES選考を通過しましたか',
                             Translator().translate('このESはES選考を通過しましたか').text))
for key in keys:
    group = df_groupby_type.get_group(key)
    es_dicision = list(group['このESはES選考を通過しましたか'])

    letter_counts = Counter(es_dicision)
    value_most, count_most = letter_counts.most_common(1)[0] 
    print("For {}({}):\nValues most: {} --> {}\n".format(key, Translator().translate(key).text,
                                                     value_most, Translator().translate(value_most).text))
    df = pd.DataFrame.from_dict(letter_counts, orient='index')
    df.plot(kind='bar')
    plt.title("Histogram of  of {}".format(Translator().translate(key).text))
    plt.xticks([])
# Out:
# In このESはES選考を通過しましたか (Did this ES pass ES selection?):
#
# For 本選考(This selection):
# Values most: はい --> Yes
#
# For 夏のインターン(Summer intern):
# Values most: はい --> Yes
#
# For 秋・冬のインターン(Autumn / Winter Intern):
# Values most: はい --> Yes

# %%
print("In {} ({}):\n".format('この企業の最終的な選考結果を教えてください',
                           Translator().translate('この企業の最終的な選考結果を教えてください').text))
for key in keys:
    group = df_groupby_type.get_group(key)
    es_dicision = list(group['この企業の最終的な選考結果を教えてください'])

    letter_counts = Counter(es_dicision)
    value_most, count_most = letter_counts.most_common(1)[0] 
    print("For {}({}):\nValues most: {} --> {}\n".format(key, Translator().translate(key).text,
                                                     value_most, Translator().translate(value_most).text))
    
    df = pd.DataFrame.from_dict(letter_counts, orient='index')
    df.plot(kind='bar')
    plt.title("Histogram of Selection Result of {}".format(Translator().translate(key).text))
    plt.xticks([])
# Out:
# In この企業の最終的な選考結果を教えてください (Please tell us the final selection result of this company):
#
# For 本選考(This selection):
# Values most: 内定 --> Tentative decision
#
# For 夏のインターン(Summer intern):
# Values most: インターン通過 --> Pass through intern
#
# For 秋・冬のインターン(Autumn / Winter Intern):
# Values most: インターン通過 --> Pass through intern

# %%
df = pd.read_csv('data.csv')
jpn_name_columns = list(df.columns)
eng_name_columns =  list([Translator().translate(x).text for x in jpn_name_columns])

for jpn, eng in zip(jpn_name_columns, eng_name_columns):
    print("{}\n{}\n".format(jpn, eng))
# Out:
# 入稿済み
# Trafficked
#
# タイムスタンプ
# Time stamp
#
# どの企業のESですか（部門も含めて）
# Which enterprise's ES (including division)
#
# いつの代の選考で使われたESですか
# When was ES used in the selection of when?
#
# いつの選考ですか
# When is your selection?
#
# 出身大学
# Born university
#
# 学部
# Department
#
# ESを提出した時のこの企業への志望度を教えてください
# Please tell me the degree of desire for this company when submitting ES
#
# このESはES選考を通過しましたか
# Did this ES pass ES selection?
#
# この企業の最終的な選考結果を教えてください
# Please tell us the final selection result of this company
#
# １ESの質問（文字数まで含めて）
# 1 ES question (including the number of characters)
#
# 1その答え
# 1 The answer
#
# 2 ESの質問（文字数まで含めて）
# 2 ES question (including the number of characters)
#
# 2 その答え
# 2 The answer
#
# 3 ESの質問（文字数まで含めて）
# 3 ES question (including the number of characters)
#
# 3 その答え
# 3 The answer
#
# 4 ESの質問（文字数まで含めて）
# 4 ES question (including the number of characters)
#
# 4 その答え
# 4 The answer
#
# 5 ESの質問（文字数まで含めて）
# 5 ES question (including the number of characters)
#
# 5 その答え
# 5 The answer
#
# 6 ESの質問（文字数まで含めて）
# 6 ES question (including the number of characters)
#
# 6 その答え
# 6 The answer
#
# 7 ESの質問（文字数まで含めて）
# 7 ES question (including the number of characters)
#
# 7 その答え
# 7 The answer
#
# 8 ESの質問（文字数まで含めて）
# 8 ES question (including the number of characters)
#
# 8 その答え
# 8 The answer
#
# 9 ESの質問（文字数まで含めて）
# 9 ES question (including the number of characters)
#
# 9 その答え
# 9 The answer
#
# 10 ESの質問（文字数まで含めて）
# 10 ES question (including the number of characters)
#
# 10 その答え
# 10 The answer
#
# 11 ESの質問（文字数まで含めて）
# 11 ES question (including the number of characters)
#
# 11 その答え
# 11 The answer
#
# 12 ESの質問（文字数まで含めて）
# 12 ES question (including the number of characters)
#
# 12 その答え
# 12 The answer

# %%
出身大学
Born university

学部
Department

ESを提出した時のこの企業への志望度を教えてください
Please tell me the degree of desire for this company when submitting ES

# %%
values_ES_decision = df.このESはES選考を通過しましたか.unique()
values_final_decision = df.この企業の最終的な選考結果を教えてください.unique()
values_type_student = df.いつの選考ですか.unique()
values_univeristy = df.出身大学.unique()
values_department = df.学部.unique()
values_degree = df.ESを提出した時のこの企業への志望度を教えてください.unique()
print(values_ES_decision)
print(values_final_decision)
print(values_type_student)
print(values_univeristy)
print(values_department)
print(values_degree)
# Out:
# ['はい' 'いいえ' '面接のときに持っていく方式でした。形式も自由だったのでOpenESを使いました。' '面接が決まってから提出したもの'
#  '最終面接前に提出' '提出しなかった。' nan]
# ['まだ結果が出ていません' 'ES通過、webテスト落ちた' '12月頭 新規事業立案型インターンシップ参加' 'インターン選考通過'
#  'ES通過ののち、辞退' '通過、インターン参加' '二次選考' '最終前辞退' '2次面接落ち' '選考中(3次面接)'
#  'ジョブ前最終選考落ち' 'インターン参加・内定' 'インターン参加' '内々定' 'インターン通過' '内定' '通過' '最終選考・辞退'
#  '最終面接落ち' 'ES通過後、辞退' '2次選考落ち' '3次面接落ち' 'ES落ち' 'Skype面接・テストセンター落ち'
#  'ES通過後選考辞退' '面接落ち' '1次面接落ち' '2次GD落ち' 'webテスト落ち' '１次落ち' '二次面接落ち'
#  'インターン特別選考内定' 'ES後のWebテスト通過、講演参加のために申し込んだため、その後の面接は受けていません。' 'インターン通貨'
#  'ES通過後の面接前に辞退' '4次個人面接落ち' 'GD落ち' '5次面接落ち' '1次選考辞退' '1次選考落ち' '二次選考辞退'
#  '最終面接まで行き辞退' 'ＥＳ通過・一次面接辞退' 'ES通過・一次面接辞退' '2次のGD落ち' '辞退' '適正検査で散りました。'
#  '満員のため、インターン選考辞退' 'インターン選考辞退' '１次面接落ち' '一次選考辞退' '二次のWeb新規事業率案落ち' '5次面接辞退'
#  'ES通過後辞退' '2次面接通過後、辞退' '2次面接（スカイプ）落ち' 'インターン通過・コンシューマーカンパニー\u3000内定'
#  '面接辞退' '最終選考' 'ES通過（二次選考辞退）' '最終面接辞退' '最終選考落ち' 'インターン通過＆内定' '最終結果待ち'
#  'ES通過のち辞退' '３次面接（最終手前）落ち' '２次面接辞退' 'ES通過後、１次面接落ち' '日程合わず辞退' '2次のGD選考落ち'
#  '3次選考辞退' '4次選考(マネージャー面接)落ち' '2次選考辞退' 'インターン内定' '個人面接落ち' 'ES・webテ落ち'
#  'インターン合格' '２次グループ面接落ち' '選考辞退' '最終選考寝坊' '筆記試験辞退' '2次面接辞退' '人事部長面接自体'
#  '筆記試験落ち' '1次面接辞退' 'インターン面接落ち' '２次面接落ち' '２次のGD選考落ち' '本選考途中辞退' 'インターン通過後内定'
#  'ES通過' '1次面談落ち' '2次面談辞退' 'ES通過後、選考辞退' '最終前の役員落ち' '社長面接落ち' '二次の筆記試験落ち'
#  '採用責任者面談辞退' 'リクルーター面談（6回目）辞退' 'リクルーター面談（1回目）辞退' '1次GD選考辞退' '3次筆記試験落ち'
#  'ES通過\u3000その後の選考辞退' '最終選考(7次選考)落ち' '最終先行落ち' 'テスト通過後辞退' 'インターン通過・内定'
#  'ジョブ通過' '2次面接・GD 落ち' 'ES・Webテスト落ち' 'Webテスト落ち' 'GD辞退' '適性検査落ち' 'GD選考落ち'
#  'テストセンター落ち' '2次のGD・テスト落ち' 'インターン通過(辞退)' '最終選考辞退' '４次面接落ち' '最終辞退' '2次SPI'
#  '三次面接落ち' 'テスト落ち' '試験落ち' 'ES通過/WEBテスト落ち' '最終落ち' '一次面接辞退' '二次面接辞退' '一次面接落ち'
#  '３次面接落ち' '２次選考辞退' '２次選考面接落ち' '合格' 'あなたが人生で一番頑張ったことを教えてください' 'ES通過後、面接辞退'
#  '一次面接放棄' '5次選考落ち' 'インターンシップ通過せず' 'ES通過せず' '最終合格' '書類選考通過（選考辞退）'
#  '二次面接落ち（選考辞退）' '内定辞退' '一次面接落ち（選考辞退）' '3次面接落ち（選考辞退）' '1次のGD落ち' 'SPI落ち'
#  '通過しませんでした。' '５次身体検査落ち' '書類選考落ち' 'Web選考落ち' '何次か忘れましたが面接落ちです。' '1次ES落ち'
#  '2次面接の結果待ち' '選考中' nan]
# ['夏のインターン' '本選考' '秋・冬のインターン' nan]
# ['北海道大学' '新潟大学' '同志社大学' '神戸大学' '東北大学' '関西大学' '大阪大学' '東京大学' '慶應義塾大学' '九州大学'
#  '京都大学' '早稲田大学' '小樽商科大学' '北海道大学大学院' '京都大学大学院' '立命館大学' '早稲田' '日本女子大学'
#  '関西学院大学' '神戸大学大学院' '慶應大学' '福島大学' '名古屋大学' '沖縄大学' '沖縄国際大学' '中央大学' '法政大学'
#  '立教大学' '明治大学' '東京工業大学' '東京工業大学大学院' '東工大' '立教' '静岡大学' '東京外国語大学' '東京女子大学'
#  '金沢大学' '慶應義塾大学大学院' '名古屋' '横浜国立大学' '金沢大学 大学院' '名古屋大学大学院' '千葉大学' '早稲田大学大学院'
#  '島根大学' '愛媛大学' '島根県立大学' '徳島大学' 'お茶の水女子大学' '宮崎大学' '広島大学' '埼玉大学' '甲南大学'
#  '大阪府立大学大学院' 'ICU' nan]
# ['法学部' '文学部英文学科' '発達科学部' '経済学部' '文学部' '工学研究科' '工学部' '経営学部' '海事科学部'
#  '政治経済学部' '理' '商学部' '工学院' 'スポーツ科学部' '農学研究科' '教育学部' '農学部' '数理学府'
#  '創造理工学部経営システム工学科' '創造理工学部' '医学研究科' '法' '文学部\u3000英文学科' '農学院' '文化構想学部'
#  '国際学部' '社会科学部' '法学部法学科' '教育' '経済経営学類' '共生システム理工学類' '法経学部' '社会学部'
#  '政治経済学部\u3000政治学科' '生命理工学部' '総合政策学部' '観光' '情報理工学院情報工学系' '理学院' '生命理工学院'
#  '材料系\u3000' '材料系' '人間科学部' '経営' '文' '政治経済学部政治学科' '理学部' '人文社会科学部' '人文社会科'
#  '観光学部' '言語文化学部' '現代教養学部' '行政政策学類' '経済' '理工学域機械工学類' '外国語学部' '国際社会学部'
#  '理工学研究科' '理工学部' '人間社会学域\u3000法学類' '法学類' '自然科学研究科' '人間社会学域人文学類' '生命農学研究科'
#  'キャリアデザイン学部' '教育人間科学部' '国際教養学部' '大学院理学研究科基盤理学専攻' '基幹理工学研究科' '法文学部'
#  '生物資源科学部' '文教育学部' '教養学部' '工学研究科物質化学系専攻応用化学分野' nan]
# [ 6.  4.  5.  3.  1.  7.  2. nan]

# %%
translator = Translator()
# es_decision = list([translator.translate(x).text if x is not pd.np.nan else x  for x in values_ES_decision])
# final_decision = list([translator.translate(x).text if x is not pd.np.nan else x  for x in values_final_decision])
# type_student = list([translator.translate(x).text if x is not pd.np.nan else x  for x in values_type_student])
# pprint(es_decision)
# pprint(final_decision)
# pprint(type_student)
universities = list([translator.translate(x).text if x is not pd.np.nan else x  for x in values_univeristy])
departments = list([translator.translate(x).text if x is not pd.np.nan else x  for x in values_department])
degrees = list([translator.translate(x).text if x is not pd.np.nan else x  for x in values_degree])
pprint(universities)
pprint(departments)
pprint(degrees)
# Out:
# ['Yes',
#  'No',
#  'It was a method of bringing it at the time of an interview. I used OpenES '
#  'because the format was also free.',
#  'Submitted after the interview was decided',
#  'Submit before final interview',
#  'I did not submit it.',
#  nan]
# ['There are no results yet',
#  'ES passing, web test failed',
#  'December head new business planning internship participation',
#  'Pass internship',
#  'Declined after passing through ES',
#  'Pass through, internship participation',
#  'Secondary screening',
#  'Final dismissal',
#  'Second interview dropout',
#  'Selection in progress (3rd interview)',
#  'Final screening failed before job',
#  'Interns participation / tentative decision',
#  'Internship participation',
#  'Indecision',
#  'Pass through intern',
#  'Tentative decision',
#  'by',
#  'Final selection / withdrawal',
#  'Final interview fell',
#  'After the ES passed, dismissed',
#  'Second round of selection',
#  'Third interview dropout',
#  'ES fall',
#  'Skype interview · test center fell off',
#  'ES passed the test and dismissed',
#  'Interview dropout',
#  'Primary interview fell',
#  'Secondary GD Dropping',
#  'Web test failure',
#  'First Order',
#  'Second interview dropped',
#  'Interns Special Selection Expected',
#  'Since I applied for web test after ES and lecture participation, I have not '
#  'received any further interviews.',
#  'Internal currency',
#  'Declined before interview after passing through ES',
#  '4th personal interview loss',
#  'GD dropped',
#  'Fiveth interview dropout',
#  'Declining first round of selection',
#  'First selection failed',
#  'Declined secondary screening',
#  'Decline until the final interview',
#  'ES passed and dismissed once',
#  'ES passed and dismissed once',
#  '2nd GD drop',
#  'dismiss',
#  'I scattered with proper inspection.',
#  'Declined internship due to full occupancy',
#  'Decline internship selection',
#  'Primary interview fell',
#  'Declining first round of selection',
#  'Secondary Web New Business Ratio Proposal Dropped',
#  'Declined 5th interview',
#  'Dismissal after ES passes',
#  'Dismissed after 2 passes',
#  'Second interview (skype) fall',
#  'Intern Intern Pass · Consumer Company Not Assigned',
#  'Decline interview',
#  'Final selection',
#  'ES passed (secondary test dismissal)',
#  'Decline final interview',
#  'Final screening failures',
#  'Intern pass & Nominee',
#  'Waiting for final result',
#  'Declined passing through ES',
#  'Third order interview (last short) fall',
#  'Secondary interview declined',
#  'After ES pass, primary interview dropped',
#  'Decline without agreeing',
#  '2nd GD selection failed',
#  'Declined third preliminary examination',
#  'Fourth Selection (Manager Interview) Fall',
#  'Declined secondary screening',
#  'Internship decision',
#  'Personal interview fell',
#  'ES · web taper',
#  'Pass intern',
#  'Second group interview dropout',
#  'Decline selection',
#  'Final screening oversight',
#  'Declining written exam',
#  'Secondary interview declined',
#  'Personnel manager interview itself',
#  'Written test failure',
#  'Decline primary interview',
#  'Interns interview falling',
#  'Second interview dropout',
#  '2nd GD selection failed',
#  'Declined during this selection',
#  'Assumptions after passing intern',
#  'ES pass',
#  'First interview dropped',
#  '2 interviews dismissed',
#  'After the ES is passed, the test is dismissed',
#  "Officer's disappearance before last",
#  'Interview with president interview',
#  'Secondary written test failure',
#  'Responsibility interview',
#  'Recruiter interview (6th) declined',
#  'Recruiter interview (1st time) declined',
#  '1 GD test dismissal',
#  'Third order written test failure',
#  'Decline selection after passing through ES',
#  'Final Selection (7th Selection) Fall',
#  'Final precedence drop',
#  'Declined after passing the test',
#  'Intern pass / tentative decision',
#  'Job passing',
#  'Secondary interview · GD disappearance',
#  'ES · Web test failure',
#  'Web test dropout',
#  'GD dismissal',
#  'Aptitude test failures',
#  'GD disapproval',
#  'Test center fell off',
#  '2nd GD · test dropout',
#  'Pass through intern (decline)',
#  'Final selection refused',
#  'Fourth interview dropout',
#  'Final dismissal',
#  '2 times SPI',
#  'Third interview dropout',
#  'Test failures',
#  'Trial failure',
#  'ES Pass / WEB Test Fall',
#  'Last fall',
#  'Decline primary interview',
#  'Secondary interview declined',
#  'Primary interview fell',
#  'Third interview dropout',
#  'Declined secondary screening',
#  'Secondary screening Interview falls',
#  'qualified',
#  'Please tell me what you did best in your life',
#  'After the ES passes, the face is dismissed',
#  'Primary interview abandonment',
#  '5 th round of selection failed',
#  'I did not pass the internship',
#  'It does not pass ES',
#  'Final qualified',
#  'Pass the screening of documents (refuse selection)',
#  'Second interview dropped (refuse selection)',
#  'Declining faction',
#  'Primary interview (declining selection)',
#  'Third interview dropout (withdrawal from selection)',
#  'First GD drop',
#  'SPI dropped',
#  'It did not pass.',
#  '5th physical examination failure',
#  'Falling of documents',
#  'Web selection failed',
#  'I forgot about what to do, but it is an interview fell.',
#  'First ES dropping',
#  'Wait for the result of the second interview',
#  'Selection',
#  nan]
# ['Summer intern', 'This selection', 'Autumn / Winter Intern', nan]
